# %%
# %pylab inline
from scipy.optimize import curve_fit
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
doc0 = np.genfromtxt("F0000CH1.CSV",delimiter=",")
x = doc0[:,3]
y = doc0[:,4]

y = y[x > -0.1]
x = x[x > -0.1]

y = y[x < 0.1]
x = x[x < 0.1]

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=2)
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("carga1.jpg")
plt.show()

# %%
y = y[x<0.]
x = x[x<0.]

a = min(y)*63./100.
print a

def func(t,c,b):
    return -c*np.exp(-t/b)

nonlfit=curve_fit(func, x, y,p0=(10.,1.))
th=np.linspace(-0.1,0.,100000)

print nonlfit[0][1]

plt.figure(figsize=(15,10))
plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1]),label='Fit')
plt.plot(x,y,"o",ms=2)
plt.hlines(a,min(x),max(x),"r",label=u'63% del voltaje máximo')
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)
plt.legend(loc='lower right',fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("carga111.jpg")
plt.show()
# Out:
# -6.749568
# 0.264285816943

# %%
y = y[x>0.]
x = x[x>0.]

a = max(y)*37./100.
def func(t,c,b):
    return c*np.exp(-t/b)

nonlfit=curve_fit(func, x, y,p0=(11.,1.))
th=np.linspace(0.,0.1,100000)

print nonlfit[0][1]

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=2)
plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1]),label='Fit')
plt.hlines(a,min(x),max(x),"r",label=u'37% del voltaje máximo')
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)
plt.legend(loc='best',fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("carga11.jpg")
plt.show()
# Out:
# 0.257799358692

# %%
doc1 = np.genfromtxt("F0001CH1.CSV",delimiter=",")
x = doc1[:,3]
y = doc1[:,4]

y = y[x > -0.1]
x = x[x > -0.1]

y = y[x < 0.1]
x = x[x < 0.1]

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=2)
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("carga2.jpg")
plt.show()

# %%
y = y[x<0.]
x = x[x<0.]

a = min(y)*63./100.
print a

def func(t,c,b):
    return -c*np.exp(-t/b)

nonlfit=curve_fit(func, x, y,p0=(10.,0.2))
th=np.linspace(-0.1,0.,100000)

print nonlfit[0][1]

plt.figure(figsize=(15,10))
plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1]),label='Fit')
plt.plot(x,y,"o",ms=2)
plt.hlines(a,min(x),max(x),"r",label=u'63% del voltaje máximo')
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)
plt.legend(loc='best',fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("carga222.jpg")
plt.show()
# Out:
# -6.552
# 0.0773915923497

# %% [markdown]
# ## y = y[x>0.]
# x = x[x>0.]
#
# a = max(y)*37./100.
# def func(t,c,b):
#     return c*np.exp(-t/b)
#
# nonlfit=curve_fit(func, x, y,p0=(10.,.2))
# th=np.linspace(0.,0.1,100000)
#
# print nonlfit[0][1]
#
# plt.figure(figsize=(15,10))
# plt.plot(x,y,"o",ms=2)
# plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1]),label='Fit')
# plt.hlines(a,min(x),max(x),"r",label=u'37% del voltaje máximo')
# plt.xlabel(u"Tiempo(s)",fontsize=25)
# plt.ylabel(u"Voltaje(V)",fontsize=25)
# plt.legend(loc='best',fontsize=25)
# plt.tick_params(axis='x', labelsize=20)
# plt.tick_params(axis='y', labelsize=20)
# plt.savefig("carga22.jpg")
# plt.show()

# %%
doc3 = np.genfromtxt("F0003CH1.CSV",delimiter=",")
x = doc3[:,3]
y = doc3[:,4]

y = y[x > 0.]
x = x[x > 0.]

b = (diff(sign(diff(y[y>10.]))) > 0).nonzero()[0] + 1
c = (diff(sign(diff(y[y>10.]))) < 0).nonzero()[0] + 1

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=2.5,label=u'Datos')
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)

from scipy.optimize import curve_fit

def func(t,a,b,c,d,e):
    return a*np.exp(-b*t)*np.sin(c*t+d)+e

nonlfit=curve_fit(func, x, y,p0=(0.,0,10000.,0.,0))
th=np.linspace(0.,0.0001,100000)
plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1],nonlfit[0][2],nonlfit[0][3],nonlfit[0][4]),"r",lw=1.5,label='Fit')
print nonlfit[0][0],nonlfit[0][1],nonlfit[0][2],nonlfit[0][3],nonlfit[0][4]
print np.sqrt(np.diag(nonlfit[1]))
plt.legend(loc='best',fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("amorti1.jpg")
plt.show()
# Out:
# -8.45713908164 41761.4758063 1387791.26608 -2.24524269229 10.1719380474
# [  1.64872045e-02   1.17397565e+02   1.20944135e+02   2.06855584e-03
#    2.95680416e-03]

# %%
doc3 = np.genfromtxt("F0004CH1.CSV",delimiter=",")
x = doc3[:,3]
y = doc3[:,4]

y = y[x > 0.]
x = x[x > 0.]

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=2.5,label=u'Datos')
plt.xlabel(u"Tiempo(s)",fontsize=25)
plt.ylabel(u"Voltaje(V)",fontsize=25)

from scipy.optimize import curve_fit

def func(t,a,b,c,d,e):
    return a*np.exp(-b*t)*np.sin(c*t+d)+e

nonlfit=curve_fit(func, x, y,p0=(0.,0.,10000.,0.,0))
th=np.linspace(0.,0.0001,100000)
plt.plot(th,func(th,nonlfit[0][0],nonlfit[0][1],nonlfit[0][2],nonlfit[0][3],nonlfit[0][4]),"r",lw=1.5,label='Fit')
print nonlfit[0][0],nonlfit[0][1],nonlfit[0][2],nonlfit[0][3],nonlfit[0][4]
print np.sqrt(np.diag(nonlfit[1]))
plt.legend(loc='best',fontsize=25)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.savefig("amorti2.jpg")
plt.show()
# Out:
# -8.5367663628 42087.6312537 1387824.38088 -2.20044655177 10.0950604959
# [  1.57784247e-02   1.12072059e+02   1.15465923e+02   1.95968806e-03
#    2.81248442e-03]

# %%
x = np.array([498333.,450000.,400000.,350000.,300000.,550000.,600000.,650000.,800000.,850000.,900000.])
y = np.array([3.42,3.11,2.68,1.92,0.444,3.67,3.9,4.15,5.56,6.03,3.96])

plt.figure(figsize=(15,10))
plt.plot(x,y,"o",ms=10)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.xlabel(u'Frecuencia (Hz)',fontsize=25)
plt.ylabel(u'Voltaje RMS (V)',fontsize=25)
plt.savefig("reson.jpg")
plt.show()
